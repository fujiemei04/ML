# %% [markdown]
# Queremos averiguar cuales son las tendencias sexuales de los usuarios de Tinder y clasificarlos usando KModes
# (veremos adelante que solo usaremos variables categóricas).
# Para eso vamos a escoger los features que solo tengan las palabra "sexo" y escoger los atributos que veamos más
# conveniente, por otro lado atributos como timestap es irrelevante asi que lo quitamos ya.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from kmodes.kmodes import KModes
import re
import seaborn as sns

# %%
df = pd.read_csv("/Users/fujiemei/Desktop/tinder.csv")

# %% [markdown]
# Creemos que el género,se puede quitar porque la orientación, la edad también no la encontramos relevante y es
# curioso ver que hay hay edades <18 cuando la aplicación es para gente adulta, suponemos que el usuario a la hora
# de entrar datos es haya equivocado. La educación tampoco la encontramos relevante también como la convivencia por lo
# que los podemos eliminar también.Tampoco hay ningún valor nulo por lo que tendremos que buscar valores fuera de lo
# común de las columnas.

# %%
df = df.drop(columns = ["Marca temporal"])
df
# Out:
#      Edad Género Orientación sexual Educación  \
# 0      15  Mujer       Heterosexual  Superior
# 1      28  Mujer       Heterosexual  Superior
# 2      29  Varon       Heterosexual  Superior
# 3      28  Varon       Heterosexual  Superior
# 4      25  Mujer       Heterosexual  Superior
# ..    ...    ...                ...       ...
# 180    26  Mujer       Heterosexual  Superior
# 181    24  Mujer       Heterosexual  Superior
# 182    19  Mujer       Heterosexual  Superior
# 183    22  Mujer       Heterosexual  Superior
# 184    27  Mujer       Heterosexual  Superior
#
#                                             Religión  \
# 0                                   Ateo / agnóstico
# 1                                   Ateo / agnóstico
# 2                                           Católico
# 3                                   Ateo / agnóstico
# 4    Otros (Islamismo, Budismo, Hinduismo, Judaismo)
# ..                                               ...
# ...

# %% [markdown]
# Vemos que no hay ningún valor nulo y exploraremos las variables en mas profunidad para ver si es todo coherente.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 68 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Edad                                                                                                                    185 non-null    int64
#  1   Género                                                                                                                  185 non-null    object
#  2   Orientación sexual                                                                                                      185 non-null    object
# ...

# %%
df = df.drop(columns = ["Edad","Género","Educación","Convivencia"])
df
# Out:
#     Orientación sexual                                         Religión  \
# 0         Heterosexual                                 Ateo / agnóstico
# 1         Heterosexual                                 Ateo / agnóstico
# 2         Heterosexual                                         Católico
# 3         Heterosexual                                 Ateo / agnóstico
# 4         Heterosexual  Otros (Islamismo, Budismo, Hinduismo, Judaismo)
# ..                 ...                                              ...
# 180       Heterosexual                                         Católico
# 181       Heterosexual                                         Católico
# 182       Heterosexual                                         Católico
# 183       Heterosexual                                         Católico
# 184       Heterosexual  Otros (Islamismo, Budismo, Hinduismo, Judaismo)
#
#                           Estado civil  \
# 0    Soltero pero saliendo casualmente
# ...

# %% [markdown]
# Veremos que tipo de respuestas hay en los atributos y los separaremos como se verá a continuación,
# vamos a crearlo todo tal que sea coherente entre conjunto de variables parecidas. Hay algunas variables
# que no nos parecen interesantes para el análisi asi que las quitamos.

# %%
x = df.columns
i = 0
x = x.to_numpy().tolist()
sex = []
for word in x:
    if re.search("sexo",word) !=None:
        sex.append(word)

sex
# Out:
# ['Usa drogas durante el sexo',
#  'Usa bebidas alcohólicas durante el sexo',
#  '¿Cuántas de las personas que conociste en Tinder, te comentaron haber  usaron drogas y/o alcohol durante el sexo?',
#  '¿Mis deseos de tener sexo interrumpen mi vida diaria?',
#  '¿Me encuentro pensando en sexo en el trabajo?',
#  '¿Pienso en el sexo más de lo que me gustaría?',
#  '¿Es difícil para mí encontrar parejas sexuales que deseen tener sexo tanto como yo quiero?',
#  'El sexo casual es aceptable',
#  'Me gustaría tener sexo con muchas parejas',
#  'El sexo como un simple intercambio de favores está bien si ambas personas están de acuerdo',
#  'El mejor sexo es sin ataduras',
#  'Es posible disfrutar del sexo con una persona y no gustar mucho esa persona',
#  'Está bien que el sexo sea solo una buena liberación física',
#  'El sexo es la forma más cercana de comunicación entre dos personas',
#  'En el mejor de los casos, el sexo parece ser la fusión de dos almas',
# ...

# %%
useless = ['Usa drogas durante el sexo',
 'Usa bebidas alcohólicas durante el sexo',
 '¿Cuántas de las personas que conociste en Tinder, te comentaron haber  usaron drogas y/o alcohol durante el sexo?',]
for word in useless:
    sex.remove(word)
sex
# Out:
# ['¿Mis deseos de tener sexo interrumpen mi vida diaria?',
#  '¿Me encuentro pensando en sexo en el trabajo?',
#  '¿Pienso en el sexo más de lo que me gustaría?',
#  '¿Es difícil para mí encontrar parejas sexuales que deseen tener sexo tanto como yo quiero?',
#  'El sexo casual es aceptable',
#  'Me gustaría tener sexo con muchas parejas',
#  'El sexo como un simple intercambio de favores está bien si ambas personas están de acuerdo',
#  'El mejor sexo es sin ataduras',
#  'Es posible disfrutar del sexo con una persona y no gustar mucho esa persona',
#  'Está bien que el sexo sea solo una buena liberación física',
#  'El sexo es la forma más cercana de comunicación entre dos personas',
#  'En el mejor de los casos, el sexo parece ser la fusión de dos almas',
#  'El sexo es una parte muy importante de la vida',
#  'El sexo suele ser una experiencia intensa, casi abrumadora',
#  'El sexo es mejor cuando te dejas llevar y te concentras en tu propio placer',
# ...

# %%
unique1 = df['El mejor sexo es sin ataduras'].unique()
unique1
# Out:
# array(['En desacuerdo', 'Ni de acuerdo ni en desacuerdo',
#        'Totalmente en desacuerdo', 'De acuerdo', 'Totalmente de acuerdo'],
#       dtype=object)

# %%
def valoresCorrectos(unique,word):
    for words in unique:
        if words==word:return True
    return False

def allOk(sex,unique):
    badCol = []
    for columns in sex:
        x = df[columns]
        for w in x:
            if (not valoresCorrectos(unique,w)): 
                badCol.append(columns)
                break
            
    return badCol
badCol = allOk(sex,unique1)
badCol
# Out:
# ['¿Mis deseos de tener sexo interrumpen mi vida diaria?',
#  '¿Me encuentro pensando en sexo en el trabajo?',
#  '¿Pienso en el sexo más de lo que me gustaría?',
#  '¿Es difícil para mí encontrar parejas sexuales que deseen tener sexo tanto como yo quiero?',
#  'El objetivo principal del sexo es divertirse']

# %%
unique2 = df['¿Pienso en el sexo más de lo que me gustaría?'].unique()
badCol2 = allOk(badCol,unique2)
badCol2
# Out:
# ['El objetivo principal del sexo es divertirse']

# %%
print(sorted(unique1))
print(sorted(df["El objetivo principal del sexo es divertirse"].unique()))
# Out:
# ['De acuerdo', 'En desacuerdo', 'Ni de acuerdo ni en desacuerdo', 'Totalmente de acuerdo', 'Totalmente en desacuerdo']
# ['De acuerdo', 'En desacuerdo', 'Ni de acuerdo ni en desacuerdo', 'Totalmente de acuerdo', 'Totalmente en descuerdo']

# %%
df["El objetivo principal del sexo es divertirse"] = df["El objetivo principal del sexo es divertirse"].replace(
                                                        "Totalmente en descuerdo",'Totalmente en desacuerdo')
df["El objetivo principal del sexo es divertirse"].unique()
# Out:
# array(['En desacuerdo', 'Ni de acuerdo ni en desacuerdo', 'De acuerdo',
#        'Totalmente de acuerdo', 'Totalmente en desacuerdo'], dtype=object)

# %%
sex1 = allOk(sex,unique1)
sex1
# Out:
# ['¿Mis deseos de tener sexo interrumpen mi vida diaria?',
#  '¿Me encuentro pensando en sexo en el trabajo?',
#  '¿Pienso en el sexo más de lo que me gustaría?',
#  '¿Es difícil para mí encontrar parejas sexuales que deseen tener sexo tanto como yo quiero?']

# %%
usecol = ["Orientación sexual","Religión","Estado civil"]
for col in usecol:
    sex.insert(0,col)
sex
# Out:
# ['Estado civil',
#  'Religión',
#  'Orientación sexual',
#  '¿Mis deseos de tener sexo interrumpen mi vida diaria?',
#  '¿Me encuentro pensando en sexo en el trabajo?',
#  '¿Pienso en el sexo más de lo que me gustaría?',
#  '¿Es difícil para mí encontrar parejas sexuales que deseen tener sexo tanto como yo quiero?',
#  'El sexo casual es aceptable',
#  'Me gustaría tener sexo con muchas parejas',
#  'El sexo como un simple intercambio de favores está bien si ambas personas están de acuerdo',
#  'El mejor sexo es sin ataduras',
#  'Es posible disfrutar del sexo con una persona y no gustar mucho esa persona',
#  'Está bien que el sexo sea solo una buena liberación física',
#  'El sexo es la forma más cercana de comunicación entre dos personas',
#  'En el mejor de los casos, el sexo parece ser la fusión de dos almas',
#  'El sexo es una parte muy importante de la vida',
#  'El sexo suele ser una experiencia intensa, casi abrumadora',
# ...

# %%
df["Religión"] = df['Religión'].replace(["Católico", "Otros (Islamismo, Budismo, Hinduismo, Judaismo)"]
                                          ,"Creyente")
df
# Out:
#     Orientación sexual          Religión                       Estado civil  \
# 0         Heterosexual  Ateo / agnóstico  Soltero pero saliendo casualmente
# 1         Heterosexual  Ateo / agnóstico  Soltero pero saliendo casualmente
# 2         Heterosexual          Creyente  Soltero pero saliendo casualmente
# 3         Heterosexual  Ateo / agnóstico  Soltero pero saliendo casualmente
# 4         Heterosexual          Creyente  Soltero pero saliendo casualmente
# ..                 ...               ...                                ...
# 180       Heterosexual          Creyente              En una relación seria
# 181       Heterosexual          Creyente  Soltero pero saliendo casualmente
# 182       Heterosexual          Creyente  Soltero pero saliendo casualmente
# 183       Heterosexual          Creyente  Soltero pero saliendo casualmente
# 184       Heterosexual          Creyente  Soltero pero saliendo casualmente
#
# ...

# %%
df =df[sex]
df
# Out:
#                           Estado civil          Religión Orientación sexual  \
# 0    Soltero pero saliendo casualmente  Ateo / agnóstico       Heterosexual
# 1    Soltero pero saliendo casualmente  Ateo / agnóstico       Heterosexual
# 2    Soltero pero saliendo casualmente          Creyente       Heterosexual
# 3    Soltero pero saliendo casualmente  Ateo / agnóstico       Heterosexual
# 4    Soltero pero saliendo casualmente          Creyente       Heterosexual
# ..                                 ...               ...                ...
# 180              En una relación seria          Creyente       Heterosexual
# 181  Soltero pero saliendo casualmente          Creyente       Heterosexual
# 182  Soltero pero saliendo casualmente          Creyente       Heterosexual
# 183  Soltero pero saliendo casualmente          Creyente       Heterosexual
# 184  Soltero pero saliendo casualmente          Creyente       Heterosexual
#
# ...

# %%
df = pd.get_dummies(df,columns = ["Estado civil","Religión","Orientación sexual"],drop_first = True)
df
# Out:
#     ¿Mis deseos de tener sexo interrumpen mi vida diaria?  \
# 0                                           Casi nunca
# 1                                                Nunca
# 2                                           Casi nunca
# 3                                           Casi nunca
# 4                                                Nunca
# ..                                                 ...
# 180                                              Nunca
# 181                                              Nunca
# 182                                              Nunca
# 183                                         Casi nunca
# 184                                              Nunca
#
#     ¿Me encuentro pensando en sexo en el trabajo?  \
# 0                                      Casi nunca
# 1                                           Nunca
# 2                                      Casi nunca
# 3                                         A veces
# ...

# %% [markdown]
# Sustuiremos el valor de las variables categoricas tal que lo neutro sea 0, y vaya incrementando el valor según
# la intensidad de la respuesta, por ejemplo un totalmente de acuerdo o siempre será un 4.

# %%
replaceMap = {'A menudo':3, 'A veces':2, 'Casi nunca':1, 'Nunca':0, 'Siempre':4}
for atr in sex1:
    df[atr] = df[atr].replace(replaceMap)

# %%
replaceMap = {'En desacuerdo':2, 'Ni de acuerdo ni en desacuerdo':0, 'De acuerdo':3,
       'Totalmente de acuerdo':4, 'Totalmente en desacuerdo':1}
sex1=np.append(sex1,["Estado civil","Religión","Orientación sexual"])
sex2 = [word for word in sex if word not in sex1]
for atr in sex2:
    df[atr] = df[atr].replace(replaceMap)

# %%
df
# Out:
#      ¿Mis deseos de tener sexo interrumpen mi vida diaria?  \
# 0                                                    1
# 1                                                    0
# 2                                                    1
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 180                                                  0
# 181                                                  0
# 182                                                  0
# 183                                                  1
# 184                                                  0
#
#      ¿Me encuentro pensando en sexo en el trabajo?  \
# 0                                                1
# 1                                                0
# 2                                                1
# 3                                                2
# ...

# %% [markdown]
# Para ver el número de cluster óptimos usaremos el Elbow Method, por lo que vemos en la gráfica que el más adecuado
# sería 5, que se parece a un punto de inflexión.

# %%
def plot_elbow_method(data):
    cost=[]
    for k in range(1, 11):
        kmodes = KModes(n_clusters=k)
        kmodes.fit(data)
        cost.append(kmodes.cost_)
    plt.plot(range(1, 11), cost,marker='X')
    plt.xticks(range(1, 11))
    plt.xlabel("Number of Clusters")
    plt.ylabel("Cost")
    plt.show()
plot_elbow_method(df)

# %%
kmode = KModes(n_clusters=5)
cluster = kmode.fit_predict(df)

# %%
Viendo e interpretando las gráficas podemos sacar las siguientes conclusiones:
    Cluster 0: Personas sexualmente indiferentes, han contestado a la mayoria de preguntas de forma neutra y son 
        poco participes de actividades sexuales, creo que son usuarios del Tinder que lo usan de manera poco habitual
        y no buscan nada en concreto.
    Cluster 1: Personas sexualmente necesitadas pero que a la vez necesitan de una conexión con la otra persona
        para iniciarlo.
    Cluster 2: Personas sexualmente MUY necesitadas, no requieren de intimidad con la otra persona y son personas
        que les gusta el sexo casual.
    Cluster 3: Personas promiscuas que están abiertas tanto a relaciones intimas o casuales donde la sexualidad
        es muy importante.
    cluster 4: Personas que necesitan de una relación para tener intimidad y no les gusta el sexo casual.

# %%
df["Cluster"] = cluster
for col in df.columns:
    plt.subplots(figsize = (15,5))
    sns.countplot(x='Cluster',hue=col, data = df)
    plt.show()
