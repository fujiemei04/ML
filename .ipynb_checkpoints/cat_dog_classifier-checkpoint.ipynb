# %% [markdown]
# We are going to builda model using convolutional neural networks to classify dogs and cats given their pictures
# with rgb color spectrum

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing import image_dataset_from_directory
import os
from os import listdir
import matplotlib.pyplot as plt

# %% [markdown]
# We are going to use the image_data_set_from_directory which will directly classify the classes since the directory
# path given are separating cats and dogs, this function returns a tf dataset which we will fit directly since it
# contains the pictures and its label in a tuple which we can feed directly to fit function.
# We will split our data into 80/20 for training and validating.

# %%
train = image_dataset_from_directory(
    "/Users/fujiemei/Desktop/cats_and_dogs-2/train",
    labels="inferred",
    label_mode="int",
    #class_names=None,
    color_mode="rgb",
    batch_size=32,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(150, 150))

validation = image_dataset_from_directory(
    "/Users/fujiemei/Desktop/cats_and_dogs-2/train",
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(150, 150))
# Out:
# Found 3000 files belonging to 2 classes.
# Using 2400 files for training.
# Found 3000 files belonging to 2 classes.
# Using 600 files for validation.

# %% [markdown]
# We can see how are our images here

# %%
class_names = train.class_names
plt.figure(figsize=(10, 10))
for images, labels in train.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# After a lot of trial and error the best architecure I found that works thebest and steadilty increases the
# accuracy is the following:
#     3 convolutional layers with 2*ni filters in each layer with n0=16, with a kernel size of 3x3.
#     Max pooling with a 2x2 matrix in each layer.
#     Following the convolutional layers 2 dense layers, the final one with one unit with sigmoid activatio since
#     it's a binary classification problem.
# The best metrics for training are: Adam optimizer with a learning rate of 0.001, binarycrossentropy loss function
#     because of its nature and with 10 epochs.
# We'll see now if with 20 epochs the trend continues to improve.

# %%
model = Sequential([
    tf.keras.layers.Rescaling(1./255),
    Conv2D(16,(3,3),activation = "relu",input_shape=(150,150,3)),
    MaxPooling2D((2,2)),
    Conv2D(32,(3,3),activation = "relu"),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation = "relu"),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(16, activation='relu'),
    Dense(1,activation = "sigmoid")
])
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=["accuracy"])
history = model.fit(train,validation_data=validation,epochs=20)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 36s 450ms/step - loss: 0.6797 - accuracy: 0.5517 - val_loss: 0.6616 - val_accuracy: 0.5350
# Epoch 2/20
# 75/75 [==============================] - 33s 424ms/step - loss: 0.6036 - accuracy: 0.6833 - val_loss: 0.5897 - val_accuracy: 0.6767
# Epoch 3/20
# 75/75 [==============================] - 39s 505ms/step - loss: 0.5586 - accuracy: 0.7233 - val_loss: 0.5641 - val_accuracy: 0.6883
# Epoch 4/20
# 75/75 [==============================] - 32s 422ms/step - loss: 0.5182 - accuracy: 0.7442 - val_loss: 0.5799 - val_accuracy: 0.6933
# Epoch 5/20
# 75/75 [==============================] - 31s 411ms/step - loss: 0.4722 - accuracy: 0.7679 - val_loss: 0.5514 - val_accuracy: 0.7317
# Epoch 6/20
# 75/75 [==============================] - 34s 450ms/step - loss: 0.4161 - accuracy: 0.8075 - val_loss: 0.5790 - val_accuracy: 0.7383
# Epoch 7/20
# 75/75 [==============================] - 32s 418ms/step - loss: 0.3710 - accuracy: 0.8342 - val_loss: 0.5754 - val_accuracy: 0.7450
# Epoch 8/20
# 75/75 [==============================] - 33s 430ms/step - loss: 0.3528 - accuracy: 0.8404 - val_loss: 0.6392 - val_accuracy: 0.7083
# Epoch 9/20
# 75/75 [==============================] - 35s 467ms/step - loss: 0.2750 - accuracy: 0.8883 - val_loss: 0.6909 - val_accuracy: 0.7233
# Epoch 10/20
# 75/75 [==============================] - 33s 436ms/step - loss: 0.2384 - accuracy: 0.9025 - val_loss: 0.7626 - val_accuracy: 0.7250
# Epoch 11/20
# 75/75 [==============================] - 32s 417ms/step - loss: 0.1809 - accuracy: 0.9354 - val_loss: 0.8290 - val_accuracy: 0.6900
# Epoch 12/20
# 75/75 [==============================] - 32s 429ms/step - loss: 0.1489 - accuracy: 0.9479 - val_loss: 0.8518 - val_accuracy: 0.7250
# Epoch 13/20
# 75/75 [==============================] - 32s 425ms/step - loss: 0.1001 - accuracy: 0.9679 - val_loss: 0.9590 - val_accuracy: 0.7017
# Epoch 14/20
# 75/75 [==============================] - 34s 448ms/step - loss: 0.0736 - accuracy: 0.9787 - val_loss: 1.0710 - val_accuracy: 0.7150
# Epoch 15/20
# 75/75 [==============================] - 36s 478ms/step - loss: 0.0746 - accuracy: 0.9787 - val_loss: 1.1429 - val_accuracy: 0.7067
# Epoch 16/20
# 75/75 [==============================] - 35s 455ms/step - loss: 0.0425 - accuracy: 0.9917 - val_loss: 1.1942 - val_accuracy: 0.7183
# Epoch 17/20
# 75/75 [==============================] - 32s 422ms/step - loss: 0.0216 - accuracy: 0.9958 - val_loss: 1.2834 - val_accuracy: 0.7167
# Epoch 18/20
# 75/75 [==============================] - 32s 421ms/step - loss: 0.0259 - accuracy: 0.9946 - val_loss: 1.3920 - val_accuracy: 0.7167
# Epoch 19/20
# 75/75 [==============================] - 38s 496ms/step - loss: 0.0162 - accuracy: 0.9971 - val_loss: 1.3973 - val_accuracy: 0.7167
# Epoch 20/20
# 75/75 [==============================] - 32s 425ms/step - loss: 0.0122 - accuracy: 0.9979 - val_loss: 1.6149 - val_accuracy: 0.7017

# %% [markdown]
# We see that with 20 epochs, this architecture overhits the models, we can see in the graph that around the 7th epoch
# the trend between the validation and training sets diverges greatly, so what are we going to try now is adding
# a regularizer, in this case we'll use a dropout regularization and an extra dense layer.

# %% [markdown]
# model[0]

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('model accuracy')
ax[0].set_ylabel('accuracy')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'test'], loc='upper left')
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('model loss')
ax[1].set_ylabel('loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'test'], loc='upper right')
plt.show()

# %%
model = Sequential([
    tf.keras.layers.Rescaling(1./255),
    Conv2D(16,(3,3),activation = "relu",input_shape=(150,150,3)),
    MaxPooling2D((2,2)),
    Conv2D(32,(3,3),activation = "relu"),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation = "relu"),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dropout(0.1),
    Dense(1,activation = "sigmoid")
])
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=["accuracy"])
history = model.fit(train,validation_data=validation,epochs=20)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 34s 425ms/step - loss: 0.6929 - accuracy: 0.5146 - val_loss: 0.6932 - val_accuracy: 0.5067
# Epoch 2/20
# 75/75 [==============================] - 31s 408ms/step - loss: 0.6936 - accuracy: 0.4963 - val_loss: 0.6925 - val_accuracy: 0.5117
# Epoch 3/20
# 75/75 [==============================] - 31s 409ms/step - loss: 0.6919 - accuracy: 0.5154 - val_loss: 0.6913 - val_accuracy: 0.5067
# Epoch 4/20
# 75/75 [==============================] - 31s 410ms/step - loss: 0.6810 - accuracy: 0.5121 - val_loss: 0.6736 - val_accuracy: 0.6117
# Epoch 5/20
# 75/75 [==============================] - 31s 411ms/step - loss: 0.6650 - accuracy: 0.5688 - val_loss: 0.6745 - val_accuracy: 0.5550
# Epoch 6/20
# 75/75 [==============================] - 30s 401ms/step - loss: 0.6598 - accuracy: 0.5962 - val_loss: 0.6650 - val_accuracy: 0.5733
# Epoch 7/20
# 75/75 [==============================] - 30s 402ms/step - loss: 0.6573 - accuracy: 0.5742 - val_loss: 0.6640 - val_accuracy: 0.5733
# Epoch 8/20
# 75/75 [==============================] - 33s 436ms/step - loss: 0.6499 - accuracy: 0.5983 - val_loss: 0.6557 - val_accuracy: 0.6133
# Epoch 9/20
# 75/75 [==============================] - 32s 428ms/step - loss: 0.6466 - accuracy: 0.6046 - val_loss: 0.6401 - val_accuracy: 0.6217
# Epoch 10/20
# 75/75 [==============================] - 31s 405ms/step - loss: 0.6307 - accuracy: 0.6254 - val_loss: 0.6421 - val_accuracy: 0.6317
# Epoch 11/20
# 75/75 [==============================] - 31s 405ms/step - loss: 0.6235 - accuracy: 0.6271 - val_loss: 0.6348 - val_accuracy: 0.6200
# Epoch 12/20
# 75/75 [==============================] - 32s 418ms/step - loss: 0.6058 - accuracy: 0.6379 - val_loss: 0.6236 - val_accuracy: 0.6300
# Epoch 13/20
# 75/75 [==============================] - 31s 406ms/step - loss: 0.5919 - accuracy: 0.6600 - val_loss: 0.6202 - val_accuracy: 0.6267
# Epoch 14/20
# 75/75 [==============================] - 31s 407ms/step - loss: 0.5640 - accuracy: 0.6883 - val_loss: 0.6058 - val_accuracy: 0.6733
# Epoch 15/20
# 75/75 [==============================] - 33s 433ms/step - loss: 0.5487 - accuracy: 0.7017 - val_loss: 0.5814 - val_accuracy: 0.6767
# Epoch 16/20
# 75/75 [==============================] - 34s 453ms/step - loss: 0.5096 - accuracy: 0.7300 - val_loss: 0.6375 - val_accuracy: 0.6700
# Epoch 17/20
# 75/75 [==============================] - 31s 409ms/step - loss: 0.4800 - accuracy: 0.7558 - val_loss: 0.6443 - val_accuracy: 0.6533
# Epoch 18/20
# 75/75 [==============================] - 31s 408ms/step - loss: 0.4317 - accuracy: 0.7837 - val_loss: 0.6298 - val_accuracy: 0.6717
# Epoch 19/20
# 75/75 [==============================] - 31s 410ms/step - loss: 0.3828 - accuracy: 0.8046 - val_loss: 0.8012 - val_accuracy: 0.7033
# Epoch 20/20
# 75/75 [==============================] - 33s 430ms/step - loss: 0.3506 - accuracy: 0.8375 - val_loss: 0.8812 - val_accuracy: 0.6950

# %% [markdown]
# I've tried adding a 0.2 rate whic resulted in the same graph as without regularization, but with 0.1 things changes
# and we see that the graph for validation and training in loss and accuracy grows equally until the 15th epoch,
# so the next thing to try is data augmentation to increase the number of pictures and see if this overfitting problem
# is avoidable.

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('model accuracy')
ax[0].set_ylabel('accuracy')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'test'], loc='upper left')
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('model loss')
ax[1].set_ylabel('loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'test'], loc='upper right')
plt.show()
